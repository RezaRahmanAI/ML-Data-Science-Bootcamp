# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import mplcyberpunk

# %%
plt.style.use('cyberpunk')
plt.plot()
# Out:
# []

# %%
x = [1,2,3,4]

mplcyberpunk.make_lines_glow()
plt.plot(x, marker = 'o', c = 'lime')

# %%
x = np.array([1,3,6,8])
y = np.array([3,5,6,9])

plt.plot(x,y, marker = 'o', ms = 10)
plt.show()

# %%
plt.plot(x, linestyle= 'dashed')
plt.show()

# %%
plt.plot(x)
plt.plot(y)

plt.show()
