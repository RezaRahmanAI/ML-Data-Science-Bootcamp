# %%
import matplotlib.pyplot as plt
import numpy as np
import mplcyberpunk

plt.style.use('cyberpunk')

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)


x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# # Setting own color of the markers

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %% [markdown]
# # Coloring each dot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# # How to Use the ColorMap

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x,y, c = colors, cmap = 'viridis')
plt.colorbar()

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x,y, c = colors, cmap = 'Accent')
plt.colorbar()

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x,y, c = colors, cmap = 'BrBG')
plt.colorbar()

plt.show()

# %% [markdown]
# # Adjusting the transparency of the dots with the (alpha) argument.

# %%
x = np.random.randint(100, size=(100))
x
# Out:
# array([ 6, 70, 15,  3, 22, 90, 51, 77, 42, 91, 83, 92, 60,  9, 52, 19, 82,
#        24, 95, 35, 36, 23, 86, 18, 82, 31, 32, 31,  6,  4, 59, 89, 96, 33,
#        86, 31, 38, 27, 54, 87, 61, 11, 42, 69, 87, 42, 44, 68, 56, 70, 41,
#        56, 35, 50,  3, 16,  5, 37,  7, 26, 12, 67, 50, 89, 80, 15, 32,  2,
#        47, 28, 11, 38, 46, 88, 57, 63, 90, 52, 50, 40, 77, 36, 80, 25, 27,
#        92, 54, 42, 29, 79, 61, 13, 87, 34, 58, 43, 94, 58, 83,  5])

# %%
sizes = 10 * np.random.randint(100, size=(100))
sizes
# Out:
# array([590,  90, 780, 750, 740, 210, 840, 120, 280, 690, 110, 510, 190,
#        730, 170,  30, 580,  30, 140, 780, 470, 310, 600,  50, 590, 210,
#         10, 870, 150, 560, 610, 540, 210, 630, 680,  60, 440, 230, 970,
#        790, 510, 210, 290, 260, 840, 190, 810, 370, 310, 910, 710,  20,
#        230, 320, 380, 370, 360, 400, 870, 920, 940,  40, 800, 660, 880,
#        230, 930, 660, 280, 120, 300, 480, 800, 100, 880, 380, 420, 100,
#         20, 620, 540, 900, 750, 310, 520, 640, 280, 220, 220, 840, 520,
#        620,  90, 660, 710, 900, 910, 410, 980, 850])

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x,y, s = sizes, c=colors, cmap = 'nipy_spectral', alpha = 0.5)
plt.colorbar()

plt.show()
